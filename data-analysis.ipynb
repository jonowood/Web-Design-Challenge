# %%
import pandas as pd

# %%
data = pd.read_csv("resources/cities.csv")

# %%
html_table = data.to_html(classes="table table-bordered table-hover", index=False)
html_table
# Out:
# '<table border="1" class="dataframe table table-bordered table-hover">\n  <thead>\n    <tr style="text-align: right;">\n      <th>City_ID</th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>0</td>\n      <td>kapaa</td>\n      <td>22.0752</td>\n      <td>-159.3190</td>\n      <td>26.99</td>\n      <td>77</td>\n      <td>40</td>\n      <td>6.17</td>\n      <td>US</td>\n      <td>1651608887</td>\n    </tr>\n    <tr>\n      <td>1</td>\n      <td>barrow</td>\n      <td>71.2906</td>\n      <td>-156.7887</td>\n      <td>-5.99</td>\n      <td>86</td>\n      <td>100</td>\n      <td>5.14</td>\n      <td>US</td>\n      <td>1651608707</td>\n    </tr>\n    <tr>\n      <td>2</td>\n      <td>busselton</td>\n      <td>-33.6500</td>\n      <td>115.3333</td>\n      <td>13.33</td>\n      
# ...

# %%
with open("table.html", "w") as file:
    file.write(html_table)
